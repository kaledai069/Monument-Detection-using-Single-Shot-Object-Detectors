# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow_addons as tfa
import math

# %%
image = Image.open('./1498.JPG')
angle_list = np.arange(10, 30, 2)
radian_list = list(map(lambda x:math.pi / 180 * x, angle_list))
plt.figure(figsize = (12, 10), dpi = 240)
for item in range(len(radian_list)):
    plt.subplot(4, 3, item + 1)
    temp_img = tfa.image.rotate(image, radian_list[item], interpolation = 'bilinear', fill_mode = 'nearest')
    plt.imshow(temp_img)
    plt.axis('off')
    plt.title(f'{angle_list[item]} degree')
